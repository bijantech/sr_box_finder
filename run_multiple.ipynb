# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
from IPython.display import display, HTML
from sr_cli import run

class Args:
    tickers='UNP,UPS,CSX,NSC,FDX,ODFL,UBER,LUV,DAL,EXPD,JBHT,CHRW,UAL,LYFT,AAL,KNX,CAR,XPO,SAIA,GXO,ALK,LSTR,UHAL,MATX,KEX,R,JBLU,HUBG,FWRD,WERN,SAVE,AAWW,ARCB,ALGT,ATSG,SKYW,JOBY,MRTN,SNDR,EGLE,HA,GNK,SNCY,DSKE,HTLD,UP,TSP,BLDE,ULCC,YELL'
    no_candles=False
    side_by_side=False
    color=False
    no_sr_lines = False
    show_zags=True
    period='5y'
    interval='1d'
    start_date='2021-11-01'
    stop_date='2022-06-17'
    dif=7.0
    retracement_size=5
    rets=range(5,10)
    diffs=range(1,15)
    nums=[2]
    number=2
    draw_boxes=True
    empty_boxes=False
    sample_only=False
    min=10
    optimize=False
    time=365
    verbose=False
    filter=False

args=Args()
run(args)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['UNP', 'UPS', 'CSX', 'NSC', 'FDX', 'ODFL', 'UBER', 'LUV', 'DAL', 'EXPD', 'JBHT', 'CHRW', 'UAL', 'LYFT', 'AAL', 'KNX', 'CAR', 'XPO', 'SAIA', 'GXO', 'ALK', 'LSTR', 'UHAL', 'MATX', 'KEX', 'R', 'JBLU', 'HUBG', 'FWRD', 'WERN', 'SAVE', 'AAWW', 'ARCB', 'ALGT', 'ATSG', 'SKYW', 'JOBY', 'MRTN', 'SNDR', 'EGLE', 'HA', 'GNK', 'SNCY', 'DSKE', 'HTLD', 'UP', 'TSP', 'BLDE', 'ULCC', 'YELL']
# [*********************100%***********************]  50 of 50 completed
#
# UNP
# UPS
# CSX
# NSC
# FDX
# ODFL
# UBER
# LUV
# DAL
# EXPD
# JBHT
# CHRW
# UAL
# LYFT
# AAL
# KNX
# CAR
# XPO
# SAIA
# GXO
# ALK
# LSTR
# UHAL
# MATX
# KEX
# R
# JBLU
# HUBG
# FWRD
# WERN
# SAVE
# AAWW
# ARCB
# ALGT
# ATSG
# SKYW
# JOBY
# MRTN
# SNDR
# EGLE
# HA
# GNK
# SNCY
# DSKE
# HTLD
# UP
# TSP
# BLDE
# ULCC
# YELL

# %%
df = pd.read_csv('data/samples.csv')
gdf = df.groupby('symbol')[['err']].min()
gdf.reset_index().merge(df)
x = pd.merge(df, gdf, left_on=['symbol', 'err'], right_on=['symbol', 'err'])
gdf
x
x.loc[:, 'img'] = x.outfile.apply(lambda x1: f'<img height=400 width=800 src="{x1}" alt="img">')
x.loc[:, 'source'] = x.symbol.apply(lambda x1: f'<img height=400 width=800 src="data/samples/{x1}.png" alt="img">')
display(HTML("<style>div.output_scroll { height: 80em; }</style>"))
display(HTML(x.to_html(index=False, escape=False)))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['ZM', 'ROKU', 'ARKK', 'SHOP', 'TSLA', 'UPWK']
# [*********************100%***********************]  6 of 6 completed
#
# ZM
# ROKU
# ARKK
# SHOP
# TSLA
# UPWK
# <style>div.output_scroll { height: 80em; }</style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>symbol</th>
#       <th>dif</th>
#       <th>ret</th>
#       <th>num</th>
#       <th>outfile</th>
#       <th>err</th>
#       <th>covered</th>
#       <th>img</th>
#       <th>source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>UPWK</td>
#       <td>1</td>
#       <td>6</td>
#       <td>2</td>
#       <td>out/UPWK/-d 1 -r 6.png</td>
#       <td>6.455285</td>
#       <td>0.422857</td>
#       <td><img height=400 width=800 src="out/UPWK/-d 1 -r 6.png" alt="img"></td>
#       <td><img height=400 width=800 src="data/samples/UPWK.png" alt="img"></td>
#     </tr>
# ...
