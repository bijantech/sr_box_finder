# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
from IPython.display import display, HTML
from sr_cli import run
from sectors import read_sectors

df = read_sectors()
df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#         Airlines      Biotech Broker-Dealers & Securities Exchanges  \
# 0       ###INDEX     ###INDEX                              ###INDEX
# 1       NYSE:XAL     AMEX:XBI                              AMEX:IAI
# 2    ###HOLDINGS  ###HOLDINGS                           ###HOLDINGS
# 3            NaN  NASDAQ:REGN                               NYSE:MS
# 4            NaN  NASDAQ:VRTX                               NYSE:GS
# ..           ...          ...                                   ...
# 185          NaN  NASDAQ:VSTM                                   NaN
# 186          NaN  NASDAQ:GERN                                   NaN
# 187          NaN  NASDAQ:VTGN                                   NaN
# 188          NaN  NASDAQ:TCRT                                   NaN
# 189          NaN  NASDAQ:ARNA                                   NaN
#
# ...

# %%
tsyms = df[['Tech Software Sector']].dropna()['Tech Software Sector'].str.split(":").str[-1].values
tsyms
# Out:
# array(['###INDEX', 'IGV', '###HOLDINGS', 'PANW', 'BL', 'LAW', 'S', 'BLKB',
#        'FICO', 'APPF', 'CRWD', 'ENV', 'AZPN', 'TENB', 'FTNT', 'BILL',
#        'APT', 'ZS', 'SSNC', 'DT', 'NCNO', 'QTWO', 'PAYC', 'CRM', 'LPSN',
#        'PING', 'ORCL', 'BTRS', 'NLOK', 'MNTV', 'NABL', 'QLYS', 'CFLT',
#        'SPLK', 'SNPS', 'VRNS', 'DOMO', 'PCTY', 'CDNS', 'JAMF', 'CDAY',
#        'TLS', 'ANSS', 'AVLR', 'PATH', 'BSY', 'INTU', 'NOW', 'ALRM',
#        'ADBE', 'EVBG', 'RPD', 'AI', 'ZUO', 'WDAY', 'MNDT', 'VMW', 'MANH',
#        'DCT', 'EA', 'PLAN', 'GWRE', 'SAIL', 'PRGS', 'TYL', 'PTC', 'CDK',
#        'VRNT', 'ZEN', 'ACIW', 'PD', 'SNAP', 'ETWO', 'ESTC', 'BKI', 'AYX',
#        'SUMO', 'WK', 'IDCC', 'CVLT', 'CTXS', 'VG', 'MSFT', 'ALTR', 'ATVI',
#        'PRO', 'CCSI', 'NEWR', 'RNG', 'DLB', 'PEGA', 'U', 'DBX', 'TDC',
#        'CRNC', 'FIVN', 'SPSC', 'XPER', 'EGHT', 'SMAR', 'ADSK', 'MTTR',
#        'ZM', 'XM', 'HUBS', 'DDOG', 'DOCU', 'TTD', 'YEXT', 'ZNGA', 'NTNX',
# ...

# %%
",".join(list(tsyms[3:].astype(str)))
# Out:
# 'UNP,UPS,CSX,NSC,FDX,ODFL,UBER,LUV,DAL,EXPD,JBHT,CHRW,UAL,LYFT,AAL,KNX,CAR,XPO,SAIA,GXO,ALK,LSTR,UHAL,MATX,KEX,R,JBLU,HUBG,FWRD,WERN,SAVE,AAWW,ARCB,ALGT,ATSG,SKYW,JOBY,MRTN,SNDR,EGLE,HA,GNK,SNCY,DSKE,HTLD,UP,TSP,BLDE,ULCC,YELL'
