# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
from IPython.display import display, HTML
from sr_cli import run
from sectors import read_sectors

df = read_sectors()
df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     Transportation 26 - - DX_66908.txt Tech Software Sector    Insurance  \
# 0         ###INDEX            ###INDEX             ###INDEX     ###INDEX
# 1         AMEX:IYT             NYSE:DX             AMEX:IGV     AMEX:IAK
# 2      ###HOLDINGS         ###HOLDINGS          ###HOLDINGS  ###HOLDINGS
# 3         NYSE:UNP                 NaN          NASDAQ:PANW      NYSE:CB
# 4         NYSE:UPS                 NaN            NASDAQ:BL     NYSE:PGR
# ..             ...                 ...                  ...          ...
# 185            NaN                 NaN                  NaN          NaN
# 186            NaN                 NaN                  NaN          NaN
# 187            NaN                 NaN                  NaN          NaN
# 188            NaN                 NaN                  NaN          NaN
# 189            NaN                 NaN                  NaN          NaN
#
#     Oil & Gas Exploration  Social Media   Technology Consumer Staples  \
# 0                ###INDEX      ###INDEX     ###INDEX         ###INDEX
# 1                AMEX:XOP   NASDAQ:SOCL     AMEX:XLK         AMEX:XLP
# 2             ###HOLDINGS   ###HOLDINGS  ###HOLDINGS      ###HOLDINGS
# 3                NYSE:TPL     NASDAQ:FB  NASDAQ:AAPL          NYSE:PG
# 4                NYSE:PXD  NASDAQ:GOOGL  NASDAQ:MSFT      NASDAQ:COST
# ..                    ...           ...          ...              ...
# 185                   NaN           NaN          NaN              NaN
# 186                   NaN           NaN          NaN              NaN
# 187                   NaN           NaN          NaN              NaN
# 188                   NaN           NaN          NaN              NaN
# 189                   NaN           NaN          NaN              NaN
#
#     Financial Bull Oil Refiners  ...    Utilities 31 - QQQ_9880c.txt  \
# 0         ###INDEX     ###INDEX  ...     ###INDEX           ###INDEX
# 1         AMEX:FAS    AMEX:CRAK  ...     AMEX:XLU         NASDAQ:QQQ
# 2      ###HOLDINGS  ###HOLDINGS  ...  ###HOLDINGS        ###HOLDINGS
# 3       NYSE:BRK.B     NYSE:MPC  ...     NYSE:NEE         NASDAQ:PDD
# 4         NYSE:JPM     NYSE:PSX  ...     NYSE:DUK          NASDAQ:JD
# ..             ...          ...  ...          ...                ...
# 185            NaN          NaN  ...          NaN                NaN
# 186            NaN          NaN  ...          NaN                NaN
# 187            NaN          NaN  ...          NaN                NaN
# 188            NaN          NaN  ...          NaN                NaN
# 189            NaN          NaN  ...          NaN                NaN
#
#         Airlines     Consumer Broker-Dealers & Securities Exchanges  \
# 0       ###INDEX     ###INDEX                              ###INDEX
# 1       NYSE:XAL     AMEX:XLY                              AMEX:IAI
# 2    ###HOLDINGS  ###HOLDINGS                           ###HOLDINGS
# 3            NaN     NYSE:NVR                               NYSE:MS
# 4            NaN  NASDAQ:AMZN                               NYSE:GS
# ..           ...          ...                                   ...
# 185          NaN          NaN                                   NaN
# 186          NaN          NaN                                   NaN
# 187          NaN          NaN                                   NaN
# 188          NaN          NaN                                   NaN
# 189          NaN          NaN                                   NaN
#
#     U.S. Real Estate U.S. Medical Devices     S&P Bear Mobile Payments  \
# 0           ###INDEX             ###INDEX     ###INDEX        ###INDEX
# 1           AMEX:IYR             AMEX:IHI    AMEX:SPXU       AMEX:IPAY
# 2        ###HOLDINGS          ###HOLDINGS  ###HOLDINGS     ###HOLDINGS
# 3           NYSE:PLD             NYSE:TMO          NaN        NYSE:AXP
# 4           NYSE:AMT             NYSE:ABT          NaN         NYSE:MA
# ..               ...                  ...          ...             ...
# 185              NaN                  NaN          NaN             NaN
# 186              NaN                  NaN          NaN             NaN
# 187              NaN                  NaN          NaN             NaN
# 188              NaN                  NaN          NaN             NaN
# 189              NaN                  NaN          NaN             NaN
#
#     Lithium & Battery Tech
# 0                 ###INDEX
# 1                 AMEX:LIT
# 2              ###HOLDINGS
# 3                 NYSE:ALB
# 4              NASDAQ:TSLA
# ..                     ...
# 185                    NaN
# 186                    NaN
# 187                    NaN
# 188                    NaN
# 189                    NaN
#
# [190 rows x 31 columns]

# %%
tsyms = df[['Transportation']].dropna().Transportation.str.split(":").str[-1].values
tsyms
# Out:
# array(['###INDEX', 'IYT', '###HOLDINGS', 'UNP', 'UPS', 'CSX', 'NSC',
#        'FDX', 'ODFL', 'UBER', 'LUV', 'DAL', 'EXPD', 'JBHT', 'CHRW', 'UAL',
#        'LYFT', 'AAL', 'KNX', 'CAR', 'XPO', 'SAIA', 'GXO', 'ALK', 'LSTR',
#        'UHAL', 'MATX', 'KEX', 'R', 'JBLU', 'HUBG', 'FWRD', 'WERN', 'SAVE',
#        'AAWW', 'ARCB', 'ALGT', 'ATSG', 'SKYW', 'JOBY', 'MRTN', 'SNDR',
#        'EGLE', 'HA', 'GNK', 'SNCY', 'DSKE', 'HTLD', 'UP', 'TSP', 'BLDE',
#        'ULCC', 'YELL'], dtype=object)

# %%
",".join(list(tsyms[3:].astype(str)))
# Out:
# 'UNP,UPS,CSX,NSC,FDX,ODFL,UBER,LUV,DAL,EXPD,JBHT,CHRW,UAL,LYFT,AAL,KNX,CAR,XPO,SAIA,GXO,ALK,LSTR,UHAL,MATX,KEX,R,JBLU,HUBG,FWRD,WERN,SAVE,AAWW,ARCB,ALGT,ATSG,SKYW,JOBY,MRTN,SNDR,EGLE,HA,GNK,SNCY,DSKE,HTLD,UP,TSP,BLDE,ULCC,YELL'
