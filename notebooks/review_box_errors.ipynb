# %%
import pandas as pd

df = pd.read_csv('../data/samples.csv')


from IPython.display import Image, display    
display(Image('../data/samples/UPWK.png'))

# %%
df[df.err < 5]
# Out:
#    symbol  dif  ret  num  err
# 0    UPWK    5    9    2  0.0
# 1    UPWK    5   10    2  0.0
# 2    UPWK    5   11    2  0.0
# 3    UPWK    5   12    2  0.0
# 4    UPWK    5   13    2  0.0
# 5    UPWK    5   14    2  0.0
# 6    UPWK    6    9    2  0.0
# 7    UPWK    6   10    2  0.0
# 8    UPWK    6   11    2  0.0
# 9    UPWK    6   12    2  0.0
# 10   UPWK    6   13    2  0.0
# 11   UPWK    6   14    2  0.0
# 12   UPWK    7    9    2  0.0
# 13   UPWK    7   10    2  0.0
# 14   UPWK    7   11    2  0.0
# 15   UPWK    7   12    2  0.0
# 16   UPWK    7   13    2  0.0
# 17   UPWK    7   14    2  0.0
# 18   UPWK    8    9    2  0.0
# 19   UPWK    8   10    2  0.0
# 20   UPWK    8   11    2  0.0
# 21   UPWK    8   12    2  0.0
# 22   UPWK    8   13    2  0.0
# 23   UPWK    8   14    2  0.0
# 24   UPWK    9    9    2  0.0
# 25   UPWK    9   10    2  0.0
# 26   UPWK    9   11    2  0.0
# 27   UPWK    9   12    2  0.0
# 28   UPWK    9   13    2  0.0
# 29   UPWK    9   14    2  0.0
# ...
